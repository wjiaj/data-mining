# %%
import pandas as pd
data_csv = pd.read_csv('data.csv')
data_csv
# Out:
#       Unnamed: 0   custid      trade_no bank_card_no  low_volume_percent  \
# 0              5  2791858  2.018050e+31          卡号1                0.01
# 1             10   534047  2.018050e+31          卡号1                0.02
# 2             12  2849787  2.018050e+31          卡号1                0.04
# 3             13  1809708  2.018050e+31          卡号1                0.00
# 4             14  2499829  2.018050e+31          卡号1                0.01
# ...          ...      ...           ...          ...                 ...
# 4749       11978  3269862  2.018050e+31          卡号1                0.05
# 4750       11986   270952  2.018050e+31          卡号1                0.01
# 4751       11988  2425913  2.018050e+31          卡号1                0.00
# 4752       11991   471395  2.018050e+31          卡号1                0.05
# 4753       11992  1881943  2.018050e+31          卡号1                0.01
#
#       middle_volume_percent  take_amount_in_later_12_month_highest  \
# ...

# %%
data_csv1 = data_csv.drop(["Unnamed: 0","custid","trade_no","bank_card_no","student_feature","id_name","latest_query_time","loans_latest_time",axis = 1])
# Out:
#   File "<ipython-input-2-98085118354a>", line 1
#     data_csv1 = data_csv.drop(["Unnamed: 0","custid","trade_no","bank_card_no","student_feature","id_name","latest_query_time","loans_latest_time",axis = 1])
#                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
data_csv.drop(["custid","trade_no","bank_card_no","student_feature","id_name","latest_query_time","loans_latest_time"],axis = 1])
# Out:
#   File "<ipython-input-5-a6ea1094d4bb>", line 1
#     data_csv.drop(["custid","trade_no","bank_card_no","student_feature","id_name","latest_query_time","loans_latest_time"],axis = 1])
#                                                                                                                                    ^
# SyntaxError: invalid syntax

# %%
data_csv1 = data_csv.drop(["Unnamed: 0","custid","trade_no","bank_card_no","student_feature","id_name","latest_query_time","loans_latest_time"],axis=1)

# %%
data_csv1
# Out:
#       low_volume_percent  middle_volume_percent  \
# 0                   0.01                   0.99
# 1                   0.02                   0.94
# 2                   0.04                   0.96
# 3                   0.00                   0.96
# 4                   0.01                   0.99
# ...                  ...                    ...
# 4749                0.05                   0.68
# 4750                0.01                   0.99
# 4751                0.00                   1.00
# 4752                0.05                   0.95
# 4753                0.01                   0.99
#
#       take_amount_in_later_12_month_highest  \
# 0                                         0
# 1                                      2000
# 2                                         0
# 3                                      2000
# 4                                         0
# ...                                     ...
# 4749                                   1000
# ...

# %%
writer = pd.ExcelWriter('1.xlsx')
data_csv1.to_excel(writer)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-c12359a176a5> in <module>
# ----> 1 writer = pd.ExcelWriter('1.xlsx')
#       2 data_csv1.to_excel(writer)
#       3 writer.save()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
#      17     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      18         # Use the openpyxl module as the Excel writer.
# ---> 19         from openpyxl.workbook import Workbook
#      20
#      21         super().__init__(path, mode=mode, **engine_kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
writer = pd.ExcelWriter('1.xlsx')
data_csv1.to_excel(writer)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c12359a176a5> in <module>
# ----> 1 writer = pd.ExcelWriter('1.xlsx')
#       2 data_csv1.to_excel(writer)
#       3 writer.save()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
writer = pd.ExcelWriter('1.xlsx')
data_csv1.to_excel(writer)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-287e21f5f930> in <module>
#       1 import pandas as pd
#       2 writer = pd.ExcelWriter('1.xlsx')
# ----> 3 data_csv1.to_excel(writer)
#       4 writer.save()
#
# NameError: name 'data_csv1' is not defined

# %%
import pandas as pd
data_csv = pd.read_csv('data.csv')
#删除无关特征
data_csv1 = data_csv.drop(["Unnamed: 0","custid","trade_no","bank_card_no","student_feature","id_name","latest_query_time","loans_latest_time"],axis=1)
writer = pd.ExcelWriter('1.xlsx')
data_csv1.to_excel(writer)
writer.save()

# %%
#删除有缺失值的行
data_csv1.dropna(how = 'any')
# Out:
#       low_volume_percent  middle_volume_percent  \
# 0                   0.01                   0.99
# 1                   0.02                   0.94
# 2                   0.04                   0.96
# 3                   0.00                   0.96
# 4                   0.01                   0.99
# ...                  ...                    ...
# 4749                0.05                   0.68
# 4750                0.01                   0.99
# 4751                0.00                   1.00
# 4752                0.05                   0.95
# 4753                0.01                   0.99
#
#       take_amount_in_later_12_month_highest  \
# 0                                         0
# 1                                      2000
# 2                                         0
# 3                                      2000
# 4                                         0
# ...                                     ...
# 4749                                   1000
# ...

# %%
#重新保存一个表格
writer = pd.ExcelWriter('2.xlsx')
data_csv1.to_excel(writer)
writer.save()
